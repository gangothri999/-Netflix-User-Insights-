# %% [markdown]
# <a href="https://colab.research.google.com/github/gangothri999/-Netflix-User-Insights-/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5a7dc4d4-8496-4318-9fe0-83eb5f4f178f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a7dc4d4-8496-4318-9fe0-83eb5f4f178f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

file_path = "Netflix Userbase (1).csv"  # Use the correct filename
df = pd.read_csv(file_path)

# %%
# Display dataset info
df.info()

# Display first five rows
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2000 non-null   int64
#  1   Subscription Type  2000 non-null   object
#  2   Monthly Revenue    2000 non-null   int64
#  3   Join Date          2000 non-null   object
#  4   Last Payment Date  2000 non-null   object
#  5   Country            2000 non-null   object
#  6   Age                2000 non-null   int64
#  7   Gender             2000 non-null   object
#  8   Device             2000 non-null   object
#  9   Plan Duration      2000 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 156.4+ KB
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %%
# Statistical summary of numerical columns
df.describe()
# Out:
#            User ID  Monthly Revenue          Age
# count  2000.000000      2000.000000  2000.000000
# mean   1000.500000        12.538500    38.729000
# std     577.494589         1.686398     7.213292
# min       1.000000        10.000000    26.000000
# 25%     500.750000        11.000000    32.000000
# 50%    1000.500000        13.000000    39.000000
# 75%    1500.250000        14.000000    45.000000
# max    2000.000000        15.000000    51.000000

# %%
print(df.columns)
# Out:
# Index(['User ID', 'Subscription Type', 'Monthly Revenue', 'Join Date',
#        'Last Payment Date', 'Country', 'Age', 'Gender', 'Device',
#        'Plan Duration'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
for col in df.columns:
    if "subscription" in col.lower():
        print(col)
# Out:
# Subscription Type

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=df.columns[df.columns.str.contains("Subscription", case=False)][0], data=df, palette='viridis')
plt.title('Distribution of Subscription Plans')
plt.xlabel('Subscription Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-13-9608dc23e300>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df.columns[df.columns.str.contains("Subscription", case=False)][0], data=df, palette='viridis')

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Age'], bins=20, kde=True, color='blue')
plt.title('Age Distribution of Netflix Users')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
print(df.columns)
# Out:
# Index(['User ID', 'Subscription Type', 'Monthly Revenue', 'Join Date',
#        'Last Payment Date', 'Country', 'Age', 'Gender', 'Device',
#        'Plan Duration'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Subscription Type', hue='Gender', data=df, palette='coolwarm')  # Use correct column names
plt.title('Subscription Type by Gender')
plt.xlabel('Subscription Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
plt.figure(figsize=(12,6))
df['Country'].value_counts().head(10).plot(kind='bar', color='green')
plt.title('Top 10 Countries by User Count')
plt.xlabel('Country')
plt.ylabel('User Count')
plt.xticks(rotation=45)
plt.show()
